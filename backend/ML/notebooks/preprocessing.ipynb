# %%
# !pip install seaborn
# Out:
# ...
# [notice] A new release of pip is available: 24.2 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pd.read_csv("shades_own.csv")
# Out:
#           brand brand_short  \
# 0    Maybelline          mb
# 1    Maybelline          mb
# 2    Maybelline          mb
# 3    Maybelline          mb
# 4    Maybelline          mb
# ..          ...         ...
# 540   Too Faced          tf
# 541   Too Faced          tf
# 542   Too Faced          tf
# 543   Too Faced          tf
# 544   Too Faced          tf
#
#                                                product product_short    R  \
# 0                                     Fitme Foundation           fmf  243
# 1                                     Fitme Foundation           fmf  247
# 2                                     Fitme Foundation           fmf  240
# 3                                     Fitme Foundation           fmf  214
# 4                                     Fitme Foundation           fmf  251
# ..                                                 ...           ...  ...
# 540  Born This Way Undetectable Medium-To-Full Cove...         bumcf  247
# ...

# %%
file_path = "shades_own.csv"
df = pd.read_csv(file_path)

# %%
print("First 5 rows of the dataset: ")
display(df.head())
# Out:
# First 5 rows of the dataset:
#         brand brand_short           product product_short    R    G    B  \
# 0  Maybelline          mb  Fitme Foundation           fmf  243  185  137
# 1  Maybelline          mb  Fitme Foundation           fmf  247  209  188
# 2  Maybelline          mb  Fitme Foundation           fmf  240  186  129
# 3  Maybelline          mb  Fitme Foundation           fmf  214  156  116
# 4  Maybelline          mb  Fitme Foundation           fmf  251  213  189
#
#                    shade_name  \
# 0  \n\n\n\n\n230 Natural Buff
# 1                   115 Ivory
# 2     \n\n\n\n\n310 Sun Beige
# 3                  330 Toffee
# 4           120 Classic Ivory
#
#                                                  URL hex_values
# 0  https://www.maybelline.co.in/all-products/face...    #f3b989
# 1  https://www.maybelline.co.in/all-products/face...    #f7d1bc
# 2  https://www.maybelline.co.in/all-products/face...    #f0ba81
# ...

# %%
df.tail()
# Out:
#          brand brand_short                                            product  \
# 540  Too Faced          tf  Born This Way Undetectable Medium-To-Full Cove...
# 541  Too Faced          tf  Born This Way Undetectable Medium-To-Full Cove...
# 542  Too Faced          tf  Born This Way Undetectable Medium-To-Full Cove...
# 543  Too Faced          tf  Born This Way Undetectable Medium-To-Full Cove...
# 544  Too Faced          tf  Born This Way Undetectable Medium-To-Full Cove...
#
#     product_short    R    G    B     shade_name  \
# 540         bumcf  247  203  161        Vanilla
# 541         bumcf  249  200  163           Nude
# 542         bumcf  252  201  164      Warm Nude
# 543         bumcf  237  189  142  Golden Beige
# 544         bumcf  234  187  144   Light  Beige
#
#                                                    URL hex_values
# 540  https://www.toofaced.com/product/23475/132718/...    #f7cba1
# 541  https://www.toofaced.com/product/23475/132718/...    #f9c8a3
# ...

# %%
df.shape
# Out:
# (545, 10)

# %%
print("\nDataset Information:")
df.info()
# Out:
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   brand          545 non-null    object
#  1   brand_short    545 non-null    object
#  2   product        545 non-null    object
#  3   product_short  545 non-null    object
#  4   R              545 non-null    int64
#  5   G              545 non-null    int64
#  6   B              545 non-null    int64
#  7   shade_name     545 non-null    object
#  8   URL            545 non-null    object
#  9   hex_values     545 non-null    object
# dtypes: int64(3), object(7)
# memory usage: 42.7+ KB

# %%
print("\nMissing Values Count:")
print(df.isnull().sum())
# Out:
# Missing Values Count:
# brand            0
# brand_short      0
# product          0
# product_short    0
# R                0
# G                0
# B                0
# shade_name       0
# URL              0
# hex_values       0
# dtype: int64

# %%
#finding missing value
df.isnull().sum()
# Out:
# brand            0
# brand_short      0
# product          0
# product_short    0
# R                0
# G                0
# B                0
# shade_name       0
# URL              0
# hex_values       0
# dtype: int64

# %%
df.fillna(df.median(numeric_only=True), inplace=True)

# %%
df.drop_duplicates(inplace=True)

# %%
categorical_columns = df.select_dtypes(include=['object']).columns
for col in categorical_columns:
 print(f"\nUnique values in {col}:")
 print(df[col].unique())
# Out:
# Unique values in brand:
# ['Maybelline' 'NY Bae' 'FACES CANADA' 'Fenty Beauty' 'Mars' 'M.A.C'
#  'LAKME' 'L’Oréal Paris' 'hundabeauty' 'Clinique' 'Revlon' 'Estee Lauder'
#  'Bobbi Brown' 'Urban Decay' 'Lotus' 'Smashbox' 'Patrick Ta Beauty'
#  'Kosas' 'Lancome' 'YvesSaintLaurent' 'Too Faced']
#
# Unique values in brand_short:
# ['mb' 'nyb' 'fc' 'fb' 'm_a' 'mac' 'lak' 'lp' 'hb' 'cq' 'rev' 'el' 'bb'
#  'ud' 'lot' 'sb' 'ptb' 'ks' 'le' 'ysl' 'tf']
#
# Unique values in product:
# ['Fitme Foundation' 'Lumi Matte Foundation' 'Fitme Tube Foundation'
#  'Superstay Full Coverage Foundation' 'Fitme Fresh Tint'
#  ' 3 IN 1 Serum Foundation' ' 3-in-1 Foundation + Moisturizer + SPF 30'
#  '\xa03-in-1 Foundation + Moisturizer + SPF 30'
#  "Soft'Lit Naturally Luminous Foundation"
#  'Lightweight BB Cream Foundation' 'Zero Blend Weightless Foundation'
#  'Artistry | Liquid Foundation' 'Strobe Dewy Skin Tint'
#  'Studio Fix Powder Plus Foundation'
#  'Studio Radiance Serum-Powered™ Foundation'
# ...

# %%
#histogram to understand the distribution
for i in df.select_dtypes(include="number").columns:
    sns.histplot(data=df,x=i)
    plt.show()

# %%
#boxplot to idetify the outliers
for i in df.select_dtypes(include="number").columns:
    sns.boxplot(data=df,x=i)
    plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load dataset
df = pd.read_csv("shades_own.csv")

# Select only numerical columns
numeric_df = df.select_dtypes(include=['float64', 'int64'])

# Calculate correlation
corr = numeric_df.corr()

# Plot heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Heatmap of Shades Dataset")
plt.show()

# %%
import numpy as np

plt.figure(figsize=(8, 6))
mask = np.triu(np.ones_like(corr, dtype=bool))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f", mask=mask)
plt.title("Correlation Heatmap of Shades Dataset")
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(data=df.select_dtypes(include=['number']))
plt.xticks(rotation=90)
plt.title("Boxplot of Numerical Features")
plt.show()

# %%
print("\nCleaned Dataset Preview:")
display(df.head())
# Out:
# Cleaned Dataset Preview:
#         brand brand_short           product product_short    R    G    B  \
# 0  Maybelline          mb  Fitme Foundation           fmf  243  185  137
# 1  Maybelline          mb  Fitme Foundation           fmf  247  209  188
# 2  Maybelline          mb  Fitme Foundation           fmf  240  186  129
# 3  Maybelline          mb  Fitme Foundation           fmf  214  156  116
# 4  Maybelline          mb  Fitme Foundation           fmf  251  213  189
#
#                    shade_name  \
# 0  \n\n\n\n\n230 Natural Buff
# 1                   115 Ivory
# 2     \n\n\n\n\n310 Sun Beige
# 3                  330 Toffee
# 4           120 Classic Ivory
#
#                                                  URL hex_values
# 0  https://www.maybelline.co.in/all-products/face...    #f3b989
# 1  https://www.maybelline.co.in/all-products/face...    #f7d1bc
# 2  https://www.maybelline.co.in/all-products/face...    #f0ba81
# ...

# %%
df.to_csv("dataset_preprocessed.csv", index=False)
print("\nCleaned dataset saved as 'shades_preprocessed.csv'")
# Out:
# Cleaned dataset saved as 'shades_preprocessed.csv'
